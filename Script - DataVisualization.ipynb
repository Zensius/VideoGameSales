# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as py

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_csv(pwd + "/Data - vgsales.csv")

# %%
dataset_modified = dataset.head(100)
dataset_modified
# Out:
#     Rank             Name Platform    Year     Genre   Publisher  NA_Sales  \
# 0    259        Asteroids     2600  1980.0   Shooter       Atari      4.00
# 1    545  Missile Command     2600  1980.0   Shooter       Atari      2.56
# 2   1768          Kaboom!     2600  1980.0      Misc  Activision      1.07
# 3   1971         Defender     2600  1980.0      Misc       Atari      0.99
# 4   2671           Boxing     2600  1980.0  Fighting  Activision      0.72
# ..   ...              ...      ...     ...       ...         ...       ...
# 95  1811      Donkey Kong      NES  1983.0  Platform    Nintendo      0.23
# 96  1841  Donkey Kong Jr.      NES  1983.0  Platform    Nintendo      0.33
# 97  1863           Popeye      NES  1983.0  Platform    Nintendo      0.51
# 98  2654      Jr. Pac-Man     2600  1983.0    Puzzle       Atari      0.72
# 99  2674  Crystal Castles     2600  1983.0    Action       Atari      0.72
#
#     EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
dataset_modified.groupby("Publisher").count().sort_values("Rank", ascending=False)
# Out:
#                               Rank  Name  Platform  Year  Genre  NA_Sales  \
# Publisher
# Atari                           31    31        31    31     31        31
# Activision                      16    16        16    16     16        16
# Mattel Interactive               8     8         8     8      8         8
# Nintendo                         6     6         6     6      6         6
# Coleco                           5     5         5     5      5         5
# Parker Bros.                     5     5         5     5      5         5
# 20th Century Fox Video Games     5     5         5     5      5         5
# Imagic                           4     4         4     4      4         4
# Tigervision                      3     3         3     3      3         3
# Data Age                         2     2         2     2      2         2
# CPG Products                     1     1         1     1      1         1
# ...

# %%
dataset_two = dataset.copy()
dataset.astype({"Year":int})
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11928/3255804583.py in <module>
#       1 dataset_two = dataset.copy()
# ----> 2 dataset.astype({"Year":int})
#
# d:\New folder (2)\anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5797                 if col_name in dtype:
#    5798                     results.append(
# -> 5799                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5800                     )
#    5801                 else:
#
# d:\New folder (2)\anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...
